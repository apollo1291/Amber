# %%
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
# collect data from csv file
dt = pd.read_csv("AmazonProductData.csv")

# show columns 
print("Columns: ", dt.columns)
# Out:
# Columns:  Index(['Uniq Id', 'Product Name', 'Brand Name', 'Asin', 'Category', 'Upc Ean Code', 'List Price', 'Selling Price', 'Quantity', 'Model Number', 'About Product', 'Product Specification', 'Technical Details', 'Shipping Weight', 'Product Dimensions', 'Image', 'Variants', 'Sku', 'Product Url', 'Stock', 'Product Details', 'Dimensions', 'Color', 'Ingredients', 'Direction To Use', 'Is Amazon Seller', 'Size Quantity Variant', 'Product Description'], dtype='object')

# %%
dt.shape
# Out:
# (10002, 28)

# %%
# drop Products that dont have a Category
dt.dropna(subset=['Category'], axis=0, inplace=True)

# Take the most general category 
dt['Category'] = dt['Category'].str.split("|").str[0].str.strip()

# %%
# Drop rows that have toys and games as a category
dt.drop(dt[dt['Category'] == "Toys & Games"].index, inplace = True)

# %%
#Reduce to only the product title and category for AI training
dt = dt[["Product Name", "Category"]]

# %%
# print number of rows
dt.shape[0]
# Out:
# 2510

# %%
#show the first 100 rows
dt.head(100)
# Out:
#                                           Product Name                   Category
# 0    DB Longboards CoreFlex Crossbow 41" Bamboo Fib...          Sports & Outdoors
# 6    Rubie's Child's Pokemon Deluxe Pikachu Costume...  Clothing, Shoes & Jewelry
# 8    ARTSCAPE Etched Glass 24" x 36" Window Film, 2...             Home & Kitchen
# 12   Baby Doll Bedding Chevron Window Valance and C...              Baby Products
# 17   Flash Furniture 25''W x 45''L Trapezoid Red HP...             Home & Kitchen
# 27                Industro Stainless Steel Hose Clamps             Home & Kitchen
# 28   Oopsy Daisy Birchwood Owl Growth Chart, Pink, ...              Baby Products
# 30   Franklin Sports Eye Black Stickers for Kids - ...          Sports & Outdoors
# 32   Jay Franco Disney Frozen 2 Forest Spirit Twin/...             Home & Kitchen
# 34   Forum Novelties Union Officer Child's Costume,...  Clothing, Shoes & Jewelry
# 44   Disney's Alice in Wonderland, "The Hatter's Ma...             Home & Kitchen
# 45        Pacific Play Tent Agility Dog Training Chute               Pet Supplies
# 51   Marvel Avengers Assemble Captain America Costu...  Clothing, Shoes & Jewelry
# 60   Great Eastern Entertainment Boys Attack On Tit...  Clothing, Shoes & Jewelry
# 65                    Rubie's Adult 2-Tone Costume Wig  Clothing, Shoes & Jewelry
# 76   RoomMates Curious George Peel and Stick Giant ...             Home & Kitchen
# 80              Mikasa VSO2000 FIVB Replica Volleyball          Sports & Outdoors
# 88               NCAA Georgia Bulldogs Toy Puzzle Cube          Sports & Outdoors
# 101          Martha Stewart Crafts Stencil Tape, 32292      Arts, Crafts & Sewing
# 104  Great Pretenders Fairy Blooms Deluxe Dress wit...  Clothing, Shoes & Jewelry
# 110  Jay Franco Nickelodeon JoJo Siwa Sweet Life Cu...             Home & Kitchen
# 115                         Ultra Pro Gamers Bag - Red          Sports & Outdoors
# 116  American Educational Vinyl Clever Catch Elemen...          Sports & Outdoors
# 118  Delta Children Bistro 2-Piece Chair Set, White...             Home & Kitchen
# 120  Educational Insights Nancy B's Science Club Bi...                Electronics
# 133  Perler 80-22860 Instruction Pad for Fuse Beads...      Arts, Crafts & Sewing
# 136               Dragon Ball Fighterz - PlayStation 4                Video Games
# 141  Sugarbooger Silicone Teether Set-of-Two, Happy...              Baby Products
# 147                 Melissa & Doug Bella Butterfly Net       Patio, Lawn & Garden
# 150            Medieval Princess Fuschia Child Costume  Clothing, Shoes & Jewelry
# 153          Dremel 7103 5/64-Inch Diamond Wheel Point   Tools & Home Improvement
# 164       Forum Novelties Men's Adult Suede Cowboy Hat  Clothing, Shoes & Jewelry
# 168  Nick Jr. Dora the Explorer Child's Dora Costum...  Clothing, Shoes & Jewelry
# 170  Forum Novelties Men's Standard Adult All Wrapp...  Clothing, Shoes & Jewelry
# 171  Sport Squad HX40 40 inch Table Top Air Hockey ...          Sports & Outdoors
# 173  Snow White and The Huntsman Deluxe Queen Raven...  Clothing, Shoes & Jewelry
# 181  RoomMates My Little Pony Fluttershy Peel and S...              Baby Products
# 184  amscan Pretty Potion Witch Halloween Costume f...  Clothing, Shoes & Jewelry
# 186  Faber-Castell Creative Studio Goldfaber Aqua W...      Arts, Crafts & Sewing
# 189         Rubies Devil Girls Child Red Demon Costume  Clothing, Shoes & Jewelry
# 194              Rubie's Costume Womens Police Costume  Clothing, Shoes & Jewelry
# 201      3DLightFX Nickelodeon Tent, Leonardo's Katana   Tools & Home Improvement
# 204  Star Wars: The Force Awakens Child's Stormtroo...  Clothing, Shoes & Jewelry
# 208  Rubie's Costume Dc Heroes and Villains Collect...  Clothing, Shoes & Jewelry
# 215            Forum Novelties Jolly Elf Adult Costume  Clothing, Shoes & Jewelry
# 218  Eureka Educational Blue Harmony Assorted Diamo...            Office Products
# 225  Huffy Disney Princess Kid Bike 12 inch & 16 in...          Sports & Outdoors
# 240            Happy Trails Zebra Plush Rocking Animal              Baby Products
# 251      Rayne Longboards Demonseed Longboard Complete          Sports & Outdoors
# 252  K2 Skate Men's Kinetic 80 Pro Inline Skate, Bl...          Sports & Outdoors
# 256  Kettler Advantage Indoor Table Tennis Bundle: ...          Sports & Outdoors
# 260  Delta Children Plastic Toddler Bed, Nickelodeo...              Baby Products
# 261            Yoshi's Crafted World - Nintendo Switch                Video Games
# 263  Swagtron Swagger 2 Plus Foldable Electric Scoo...          Sports & Outdoors
# 265                      Wildkin Kids 17 Inch Backpack  Clothing, Shoes & Jewelry
# 286  Skywalker Trampolines 9x15 Blue Rectangle Spri...          Sports & Outdoors
# 293  Ergobaby Metro Compact City Stroller Accessori...              Baby Products
# 300                 Emoji Pals Kissy Kids Saucer Chair             Home & Kitchen
# 303                 Darice 9163-46 Wood Airplane Craft      Arts, Crafts & Sewing
# 305  Anna Frozen Fever Deluxe Costume, One Color, 3...  Clothing, Shoes & Jewelry
# 310  Top Notch Teacher Products Chart Tablet Polka ...            Office Products
# 314                       Barbie Bride Costume, Medium  Clothing, Shoes & Jewelry
# 319    Pitsco TETRIX Gear Pack (40, 80, and 120-tooth)            Office Products
# 322  Triple Eight Sweatsaver Liner Skateboarding He...          Sports & Outdoors
# 323  Rollerblade Twister Edge Men's Adult Fitness I...          Sports & Outdoors
# 329               Gamma Shockbuster Vibration Dampener          Sports & Outdoors
# 330  Juniors Go Go Girl Black Costume (Standard;Chi...  Clothing, Shoes & Jewelry
# 342  All About Details CATHE60 Hello 60 Cake, 1pc, ...     Grocery & Gourmet Food
# 349                               "Numeric Candle, #4"             Home & Kitchen
# 352  Fisher-Price Infant-to-Toddler Rocker, Jungle Fun              Baby Products
# 382  Prism Skate Co Biscuit Artist Series Skateboar...          Sports & Outdoors
# 383  Sammons Preston Replacement Cover for Mini Exe...          Sports & Outdoors
# 412  Rubie's Costume Co Baby Boys' Sonic Romper Cos...  Clothing, Shoes & Jewelry
# 420  Pyle Megaphone Speaker PA Bullhorn - with Buil...          Sports & Outdoors
# 421  Creativity Street Round Beginner Paint Brushes...      Arts, Crafts & Sewing
# 426  Inflatable MegaMorph Fat Suit Costume For Adul...  Clothing, Shoes & Jewelry
# 429        Tachikara T-Rope Tetherball Attachment Rope          Sports & Outdoors
# 430  Lunchskins LS4-TOTE-STRIPE-NAV Reusable Tote, ...             Home & Kitchen
# 434  Hampton Nautical Red Painted Lifering with Whi...             Home & Kitchen
# 440  Kid's Cowboy Wall Vinyl Sticker Growth Chart 2...              Baby Products
# 444      Nerf Sports Pro Grip Football (blue football)          Sports & Outdoors
# 446  Rubie's Costume Co Cleopatra Headpiece-Mesh Co...  Clothing, Shoes & Jewelry
# 448  Marvel Avengers 2-In-1 Muscle Chest Hulk/Capta...  Clothing, Shoes & Jewelry
# 455  Beistle 50354 Party Supplies, 8" x 5½" x 5½", ...             Home & Kitchen
# 460              Neon Super Hero Mask, Party Accessory  Clothing, Shoes & Jewelry
# 464  Rubie's Women's Batman v Superman: Dawn of Jus...  Clothing, Shoes & Jewelry
# 469              Lord of The Rings Bilbo Baggins Sword  Clothing, Shoes & Jewelry
# 470    California Costumes Toys Little Mermaid Costume  Clothing, Shoes & Jewelry
# 475  AMERICAN GREETINGS Rainbow Latex Balloons| Pac...             Home & Kitchen
# 479  Rubie's Costume Co. Women's Full Length Hooded...  Clothing, Shoes & Jewelry
# 480               Smith Safety Gear Leopard Elbow Pads          Sports & Outdoors
# 481           World of Nintendo Mario Bros U Boo Plush                Video Games
# 482  amscan Antler Glitter Plastic Fun Shades | Chr...  Clothing, Shoes & Jewelry
# 487        Rubie's Costume Co - Batman Child Gauntlets  Clothing, Shoes & Jewelry
# 491  RoyalBaby Space Shuttle Kids Bike for Boys and...          Sports & Outdoors
# 493  SunWorks PAC6525 Construction Paper, 11 Assort...      Arts, Crafts & Sewing
# 494  Disney/Pixar Zootopia 'Bunny Ears' 3 Piece She...             Home & Kitchen
# 495  Safavieh Castle Gardens Collection Dragon Coin...             Home & Kitchen
# 496  Pitsco Laser-Cut Basswood T-Bot II Hydraulic A...            Office Products
# 504       RoomMates Flower Power Peel and Stick Border              Baby Products

# %%
data = dt[['Product Name', 'Category']]

data['Category'].unique()
# Out:
# array(['Sports & Outdoors', 'Clothing, Shoes & Jewelry', 'Home & Kitchen',
#        'Baby Products', 'Pet Supplies', 'Arts, Crafts & Sewing',
#        'Electronics', 'Video Games', 'Patio, Lawn & Garden',
#        'Tools & Home Improvement', 'Office Products',
#        'Grocery & Gourmet Food', 'Remote & App Controlled Vehicle Parts',
#        'Health & Household', 'Industrial & Scientific',
#        'Beauty & Personal Care', 'Hobbies',
#        'Remote & App Controlled Vehicles & Parts', 'Automotive',
#        'Musical Instruments', 'Movies & TV', 'Cell Phones & Accessories'],
#       dtype=object)

# %%
dt2 = pd.read_csv("AmazonProductData2.csv", index_col=False)
print("Columns: ", dt2.columns)
# Out:
# Columns:  Index(['Uniq Id', 'Crawl Timestamp', 'Asin', 'Title', 'Image Url', 'Weight', 'Description', 'Price', 'Buybox Winner', 'Other Seller1', 'Other Seller1 Price', 'Other Seller2', 'Other Seller2 Price', 'Other Seller3', 'Other Seller3 Price', 'Category'], dtype='object')
# C:\Users\hemph\AppData\Local\Temp\ipykernel_33028\3982817246.py:1: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   dt2 = pd.read_csv("AmazonProductData2.csv", index_col=False)

# %%
# drop Products that dont have a Category
dt2.dropna(subset=['Category'], axis=0, inplace=True)

# Delete products that are hard to categorize
dt2.drop(dt2[dt2["Category"].str.contains("›")==False].index, inplace = True)

# %%
# Take the most general category
dt2['Category'] = dt2['Category'].str.split("›").str[0].str.strip()

# %%
dt2 = dt2[["Title", "Category"]]

# %%
dt2.shape[0]
# Out:
# 11642

# %%
dt2.head(20)
# Out:
#                                                 Title                  Category
# 0    Pilot Needle Ballpoint Pen, Hi-Tec V10, Blue ...           Office Products
# 8    Union Creative Giant Killing Figure 05: Daisu...              Toys & Games
# 9    Tape Logic Shipping & Handling Label, Legend"...   Industrial & Scientific
# 16   Rubie's Star Wars Classic Luke Skywalker Chil...              Toys & Games
# 19   Fit & Fresh JAXX Set of Five Containers, Extr...            Home & Kitchen
# 20   PURELL ES8 Professional HEALTHY SOAP Foam Ref...   Industrial & Scientific
# 22   Gum Power Rangers Timer Light Toothbrush - So...    Beauty & Personal Care
# 23   Foil Bunny Silhouettes (asstd colors) Party A...              Toys & Games
# 30   DMC TC8836-6750 Silver Label Aida 18 Count 15...     Arts, Crafts & Sewing
# 31   Creative Ideas Solid 3/8-Inch Grosgrain Ribbo...     Arts, Crafts & Sewing
# 33   NUOLUX Party Swirl Dizzy Danglers Haning Deco...              Toys & Games
# 34   BRUT After Shave Classic Fragrance 5 oz (Pack...    Beauty & Personal Care
# 38           Cobra Products PST170 Tub Drain Remover   Tools & Home Improvement
# 41   HABA Butterfly Threading Game - 47 Pieces of ...              Toys & Games
# 43   Dr. Scholl's P.r.o. Arch Pain Relief Orthotic...        Health & Household
# 45   Redken Shades EQ Equalizing Conditiong Color ...    Beauty & Personal Care
# 47   Cando 10-5282 3 Piece Low Powder Moderate Exe...        Health & Household
# 48   2011 McLaren MP4-12C GT3 #60 in 1:43 Scale by...              Toys & Games
# 52   Continental Refrigeration 5-111 Shelf, 19-1/8...                Appliances
# 54   Bulk Buy: Darice DIY Crafts Raffia Bunch Natu...     Arts, Crafts & Sewing

# %%
dt.columns.unique()
# Out:
# Index(['Product Name', 'Category'], dtype='object')

# %%
dt2.columns.unique()
# Out:
# Index(['Title', 'Category'], dtype='object')

# %%
# rename the dt2 title so that it combines smoothly with dt
dt2 = dt2.rename(columns={"Title": "Product Name"})

# %%
frames = [dt, dt2]

# %%
#Combine dataframes into 1 frame
productData = pd.concat(frames)

# %%
productData.shape
# Out:
# (14152, 2)

# %%
productData.head(14152)
# Out:
#                                             Product Name                   Category
# 0      DB Longboards CoreFlex Crossbow 41" Bamboo Fib...          Sports & Outdoors
# 6      Rubie's Child's Pokemon Deluxe Pikachu Costume...  Clothing, Shoes & Jewelry
# 8      ARTSCAPE Etched Glass 24" x 36" Window Film, 2...             Home & Kitchen
# 12     Baby Doll Bedding Chevron Window Valance and C...              Baby Products
# 17     Flash Furniture 25''W x 45''L Trapezoid Red HP...             Home & Kitchen
# ...                                                  ...                        ...
# 29990   Babydoll Bedding Tailored Cradle Bumper, Ecru...              Baby Products
# 29991   Two-Sided Mylar Foil Round Balloon, Monkeyin'...             Home & Kitchen
# 29992   WEmake Lead Free Solder Science Kit with 5' R...               Toys & Games
# 29995   Avery Legal Dividers, Premium Individual Tab ...            Office Products
# 29998   STEELMASTER Storage Tub with Locker Design, 7...            Office Products
#
# [14152 rows x 2 columns]

# %%
#export to csv
productData.to_csv('Data/ProductData.csv')

# %%
productData["Category"].unique()
# Out:
# array(['Sports & Outdoors', 'Clothing, Shoes & Jewelry', 'Home & Kitchen',
#        'Baby Products', 'Pet Supplies', 'Arts, Crafts & Sewing',
#        'Electronics', 'Video Games', 'Patio, Lawn & Garden',
#        'Tools & Home Improvement', 'Office Products',
#        'Grocery & Gourmet Food', 'Remote & App Controlled Vehicle Parts',
#        'Health & Household', 'Industrial & Scientific',
#        'Beauty & Personal Care', 'Hobbies',
#        'Remote & App Controlled Vehicles & Parts', 'Automotive',
#        'Musical Instruments', 'Movies & TV', 'Cell Phones & Accessories',
#        'Toys & Games', 'Appliances', 'Books',
#        'Mobility & Daily Living Aids', 'Power & Hand Tools',
#        'Medical Supplies & Equipment', 'Kitchen & Dining',
#        'Motorcycle & Powersports', 'CDs & Vinyl',
#        'Small Appliance Parts & Accessories', 'Office Electronics',
#        'Instrument Accessories'], dtype=object)
